# %%
import numpy as np
import plotly.graph_objs as go

# %% [markdown]
# ### Функция одной переменной

# %%
def f(x):
    return 3 * x**2

def df(x):
    return 6 * x

def gradient_descent_1d(x0, learning_rate, tolerance):
    res = []
    while True:
        res.append([x0, f(x0)])
        x1 = x0 - learning_rate * df(x0)
        if np.linalg.norm(x1 - x0) < tolerance:
            break
        x0 = x1
    return np.array(res)

# %% [markdown]
# ### Функция двух переменных

# %%
def f_2d(x, y):
    return 3 * x**2 + 5 * y**2

def df_2d(x, y):
    return np.array([6 * x, 10 * y])

def gradient_descent_2d(x0, y0, learning_rate, tolerance):
    res = []
    while True:
        res.append([x0, y0, f_2d(x0, y0)])
        gradient = df_2d(x0, y0)
        x1 = x0 - learning_rate * gradient[0]
        y1 = y0 - learning_rate * gradient[1]
        if np.linalg.norm([x1 - x0, y1 - y0]) < tolerance:
            break
        x0, y0 = x1, y1
    return np.array(res)

# %% [markdown]
# ### Градиентный спуск для одной переменной

# %%
x0 = 5
learning_rate = 0.1
tolerance = 1e-8
res_1d = gradient_descent_1d(x0, learning_rate, tolerance)

# %% [markdown]
# ### Градиентный спуск для двух переменных

# %%
x0, y0 = 5, 10
res_2d = gradient_descent_2d(x0, y0, learning_rate, tolerance)

# %% [markdown]
# ### Функция одной переменной

# %%
fig = go.Figure()

# %% [markdown]
# ### График для функции одной переменной

# %%
x_vals = np.linspace(-5, 5, 100)
fig.add_trace(go.Scatter(x=x_vals, y=f(x_vals), mode='lines', name='f(x)'))
fig.add_trace(go.Scatter(x=res_1d[:, 0], y=res_1d[:, 1], mode='markers+lines', name='Сходимость'))
# Out:
# <div>                            <div id="ca511541-a0f5-494f-a8a6-51d83797da9e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ca511541-a0f5-494f-a8a6-51d83797da9e")) {                    Plotly.newPlot(                        "ca511541-a0f5-494f-a8a6-51d83797da9e",                        [{"mode":"lines","name":"f(x)","x":[-5.0,-4.898989898989899,-4.797979797979798,-4.696969696969697,-4.595959595959596,-4.494949494949495,-4.393939393939394,-4.292929292929293,-4.191919191919192,-4.090909090909091,-3.9898989898989896,-3.888888888888889,-3.787878787878788,-3.686868686868687,-3.5858585858585856,-3.484848484848485,-3.383838383838384,-3.282828282828283,-3.1818181818181817,-3.080808080808081,-2.9797979797979797,-2.878787878787879,-2.7777777777777777,-2.676767676767677,-2.5757575757575757,-2.474747474747475,-2.3737373737373737,-2.272727272727273,-2.1717171717171717,-2.070707070707071,-1.9696969696969697,-1.868686868686869,-1.7676767676767677,-1.6666666666666665,-1.5656565656565657,-1.4646464646464645,-1.3636363636363638,-1.2626262626262625,-1.1616161616161618,-1.0606060606060606,-0.9595959595959593,-0.858585858585859,-0.7575757575757578,-0.6565656565656566,-0.5555555555555554,-0.45454545454545503,-0.3535353535353538,-0.2525252525252526,-0.15151515151515138,-0.050505050505050164,0.050505050505050164,0.15151515151515138,0.2525252525252526,0.3535353535353538,0.45454545454545414,0.5555555555555554,0.6565656565656566,0.7575757575757578,0.8585858585858581,0.9595959595959593,1.0606060606060606,1.1616161616161618,1.262626262626262,1.3636363636363633,1.4646464646464645,1.5656565656565657,1.666666666666667,1.7676767676767673,1.8686868686868685,1.9696969696969697,2.070707070707071,2.1717171717171713,2.2727272727272725,2.3737373737373737,2.474747474747475,2.5757575757575752,2.6767676767676765,2.7777777777777777,2.878787878787879,2.9797979797979792,3.0808080808080813,3.1818181818181817,3.282828282828282,3.383838383838384,3.4848484848484844,3.5858585858585865,3.686868686868687,3.787878787878787,3.8888888888888893,3.9898989898989896,4.09090909090909,4.191919191919192,4.292929292929292,4.3939393939393945,4.494949494949495,4.595959595959595,4.696969696969697,4.797979797979798,4.8989898989899,5.0],"y":[75.0,72.00030609121518,69.06183042546678,66.18457300275483,63.368533823079275,60.613712886440155,57.920110192837456,55.287725742271206,52.71655953474135,50.20661157024794,47.75788184879093,45.37037037037037,43.04407713498623,40.779002142638504,38.575145393327205,36.43250688705234,34.3510866238139,32.33088460361188,30.37190082644628,28.474135292317108,26.63758800122436,24.86225895316805,23.148148148148145,21.49525558616468,19.903581267217632,18.37312519130701,16.90388735843281,15.495867768595044,14.149066421793695,12.863483318028774,11.639118457300276,10.475971839608206,9.374043464952557,8.333333333333332,7.353841444750537,6.435567799204162,5.578512396694215,4.782675237220691,4.048056320783594,3.3746556473829195,2.76247321701867,2.21150902969085,1.7217630853994499,1.293235384144475,0.9259259259259252,0.619834710743803,0.3749617385981028,0.19130700948882778,0.06887052341597784,0.007652280379553004,0.007652280379553004,0.06887052341597784,0.19130700948882778,0.3749617385981028,0.6198347107438006,0.9259259259259252,1.293235384144475,1.7217630853994499,2.2115090296908457,2.76247321701867,3.3746556473829195,4.048056320783594,4.782675237220688,5.5785123966942125,6.435567799204162,7.353841444750537,8.333333333333336,9.374043464952551,10.475971839608201,11.639118457300276,12.863483318028774,14.149066421793687,15.495867768595037,16.90388735843281,18.37312519130701,19.90358126721762,21.495255586164674,23.148148148148145,24.86225895316805,26.637588001224355,28.474135292317122,30.37190082644628,32.330884603611864,34.3510866238139, ...

# %% [markdown]
# ### График для функции двух переменных

# %%
fig1 = go.Figure()

# %%
x_vals = np.linspace(-5, 5, 100)
y_vals = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x_vals, y_vals)
Z = f_2d(X, Y)
fig1.add_trace(go.Surface(x=X, y=Y, z=Z, colorscale='Viridis', opacity=0.8))
fig1.add_trace(go.Scatter3d(x=res_2d[:, 0], y=res_2d[:, 1], z=res_2d[:, 2], mode='markers+lines', name='Сходимость'))
# Out:
# <div>                            <div id="0e07cfa4-5ec5-404c-8bad-73bbd834b53f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e07cfa4-5ec5-404c-8bad-73bbd834b53f")) {                    Plotly.newPlot(                        "0e07cfa4-5ec5-404c-8bad-73bbd834b53f",                        [{"colorscale":[[0.0,"#440154"],[0.1111111111111111,"#482878"],[0.2222222222222222,"#3e4989"],[0.3333333333333333,"#31688e"],[0.4444444444444444,"#26828e"],[0.5555555555555556,"#1f9e89"],[0.6666666666666666,"#35b779"],[0.7777777777777778,"#6ece58"],[0.8888888888888888,"#b5de2b"],[1.0,"#fde725"]],"opacity":0.8,"x":[[-5.0,-4.898989898989899,-4.797979797979798,-4.696969696969697,-4.595959595959596,-4.494949494949495,-4.393939393939394,-4.292929292929293,-4.191919191919192,-4.090909090909091,-3.9898989898989896,-3.888888888888889,-3.787878787878788,-3.686868686868687,-3.5858585858585856,-3.484848484848485,-3.383838383838384,-3.282828282828283,-3.1818181818181817,-3.080808080808081,-2.9797979797979797,-2.878787878787879,-2.7777777777777777,-2.676767676767677,-2.5757575757575757,-2.474747474747475,-2.3737373737373737,-2.272727272727273,-2.1717171717171717,-2.070707070707071,-1.9696969696969697,-1.868686868686869,-1.7676767676767677,-1.6666666666666665,-1.5656565656565657,-1.4646464646464645,-1.3636363636363638,-1.2626262626262625,-1.1616161616161618,-1.0606060606060606,-0.9595959595959593,-0.858585858585859,-0.7575757575757578,-0.6565656565656566,-0.5555555555555554,-0.45454545454545503,-0.3535353535353538,-0.2525252525252526,-0.15151515151515138,-0.050505050505050164,0.050505050505050164,0.15151515151515138,0.2525252525252526,0.3535353535353538,0.45454545454545414,0.5555555555555554,0.6565656565656566,0.7575757575757578,0.8585858585858581,0.9595959595959593,1.0606060606060606,1.1616161616161618,1.262626262626262,1.3636363636363633,1.4646464646464645,1.5656565656565657,1.666666666666667,1.7676767676767673,1.8686868686868685,1.9696969696969697,2.070707070707071,2.1717171717171713,2.2727272727272725,2.3737373737373737,2.474747474747475,2.5757575757575752,2.6767676767676765,2.7777777777777777,2.878787878787879,2.9797979797979792,3.0808080808080813,3.1818181818181817,3.282828282828282,3.383838383838384,3.4848484848484844,3.5858585858585865,3.686868686868687,3.787878787878787,3.8888888888888893,3.9898989898989896,4.09090909090909,4.191919191919192,4.292929292929292,4.3939393939393945,4.494949494949495,4.595959595959595,4.696969696969697,4.797979797979798,4.8989898989899,5.0],[-5.0,-4.898989898989899,-4.797979797979798,-4.696969696969697,-4.595959595959596,-4.494949494949495,-4.393939393939394,-4.292929292929293,-4.191919191919192,-4.090909090909091,-3.9898989898989896,-3.888888888888889,-3.787878787878788,-3.686868686868687,-3.5858585858585856,-3.484848484848485,-3.383838383838384,-3.282828282828283,-3.1818181818181817,-3.080808080808081,-2.9797979797979797,-2.878787878787879,-2.7777777777777777,-2.676767676767677,-2.5757575757575757,-2.474747474747475,-2.3737373737373737,-2.272727272727273,-2.1717171717171717,-2.070707070707071,-1.9696969696969697,-1.868686868686869,-1.7676767676767677,-1.6666666666666665,-1.5656565656565657,-1.4646464646464645,-1.3636363636363638,-1.2626262626262625,-1.1616161616161618,-1.0606060606060606,-0.9595959595959593,-0.858585858585859,-0.7575757575757578,-0.6565656565656566,-0.5555555555555554,-0.45454545454545503,-0.3535353535353538,-0.2525252525252526,-0.15151515151515138,-0.050505050505050164,0.050505050505050164,0.15151515151515138,0.2525252525252526,0.3535353535353538,0.45454545454545414,0.5555555555555554,0.6565656565656566,0.7575757575757578,0.8585858585858581,0.9595959595959593,1.0606060606060606,1.1616161616161618,1.262626262626262,1.3636363636363633,1.4646464646464645,1.5656565656 ...

# %%
fig.update_layout(scene=dict(xaxis_title='x', yaxis_title='y', zaxis_title='f(x, y)',), title='Градиентный спуск',)

fig.show()
# Out:
# <div>                            <div id="96e94fe6-a2a4-4035-a23a-4ee07d30fb87" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96e94fe6-a2a4-4035-a23a-4ee07d30fb87")) {                    Plotly.newPlot(                        "96e94fe6-a2a4-4035-a23a-4ee07d30fb87",                        [{"mode":"lines","name":"f(x)","x":[-5.0,-4.898989898989899,-4.797979797979798,-4.696969696969697,-4.595959595959596,-4.494949494949495,-4.393939393939394,-4.292929292929293,-4.191919191919192,-4.090909090909091,-3.9898989898989896,-3.888888888888889,-3.787878787878788,-3.686868686868687,-3.5858585858585856,-3.484848484848485,-3.383838383838384,-3.282828282828283,-3.1818181818181817,-3.080808080808081,-2.9797979797979797,-2.878787878787879,-2.7777777777777777,-2.676767676767677,-2.5757575757575757,-2.474747474747475,-2.3737373737373737,-2.272727272727273,-2.1717171717171717,-2.070707070707071,-1.9696969696969697,-1.868686868686869,-1.7676767676767677,-1.6666666666666665,-1.5656565656565657,-1.4646464646464645,-1.3636363636363638,-1.2626262626262625,-1.1616161616161618,-1.0606060606060606,-0.9595959595959593,-0.858585858585859,-0.7575757575757578,-0.6565656565656566,-0.5555555555555554,-0.45454545454545503,-0.3535353535353538,-0.2525252525252526,-0.15151515151515138,-0.050505050505050164,0.050505050505050164,0.15151515151515138,0.2525252525252526,0.3535353535353538,0.45454545454545414,0.5555555555555554,0.6565656565656566,0.7575757575757578,0.8585858585858581,0.9595959595959593,1.0606060606060606,1.1616161616161618,1.262626262626262,1.3636363636363633,1.4646464646464645,1.5656565656565657,1.666666666666667,1.7676767676767673,1.8686868686868685,1.9696969696969697,2.070707070707071,2.1717171717171713,2.2727272727272725,2.3737373737373737,2.474747474747475,2.5757575757575752,2.6767676767676765,2.7777777777777777,2.878787878787879,2.9797979797979792,3.0808080808080813,3.1818181818181817,3.282828282828282,3.383838383838384,3.4848484848484844,3.5858585858585865,3.686868686868687,3.787878787878787,3.8888888888888893,3.9898989898989896,4.09090909090909,4.191919191919192,4.292929292929292,4.3939393939393945,4.494949494949495,4.595959595959595,4.696969696969697,4.797979797979798,4.8989898989899,5.0],"y":[75.0,72.00030609121518,69.06183042546678,66.18457300275483,63.368533823079275,60.613712886440155,57.920110192837456,55.287725742271206,52.71655953474135,50.20661157024794,47.75788184879093,45.37037037037037,43.04407713498623,40.779002142638504,38.575145393327205,36.43250688705234,34.3510866238139,32.33088460361188,30.37190082644628,28.474135292317108,26.63758800122436,24.86225895316805,23.148148148148145,21.49525558616468,19.903581267217632,18.37312519130701,16.90388735843281,15.495867768595044,14.149066421793695,12.863483318028774,11.639118457300276,10.475971839608206,9.374043464952557,8.333333333333332,7.353841444750537,6.435567799204162,5.578512396694215,4.782675237220691,4.048056320783594,3.3746556473829195,2.76247321701867,2.21150902969085,1.7217630853994499,1.293235384144475,0.9259259259259252,0.619834710743803,0.3749617385981028,0.19130700948882778,0.06887052341597784,0.007652280379553004,0.007652280379553004,0.06887052341597784,0.19130700948882778,0.3749617385981028,0.6198347107438006,0.9259259259259252,1.293235384144475,1.7217630853994499,2.2115090296908457,2.76247321701867,3.3746556473829195,4.048056320783594,4.782675237220688,5.5785123966942125,6.435567799204162,7.353841444750537,8.333333333333336,9.374043464952551,10.475971839608201,11.639118457300276,12.863483318028774,14.149066421793687,15.495867768595037,16.90388735843281,18.37312519130701,19.90358126721762,21.495255586164674,23.148148148148145,24.86225895316805,26.637588001224355,28.474135292317122,30.37190082644628,32.330884603611864,34.3510866238139, ...
